# %%
import os
import sys
import pathlib

# PACKAGE_PARENT = pathlib.Path(__file__).parent

# only for jupyter notebook
PACKAGE_PARENT = pathlib.Path.cwd().parent

print(PACKAGE_PARENT)
sys.path.append(str(PACKAGE_PARENT))
# sys.path.append(str(PACKAGE_PARENT/"pubsub"))
# Out:
# /Users/gaurav/projects/ebay_alerts_backend

# %%
from pubsub import RedisConsumer, Event

# %%
consumer = RedisConsumer('alerts_stream', None)

# %%
# while message := consumer.consume():
#     print(message)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# ...
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# <generator object RedisConsumer.consume at 0x11037f3e0>
# <generator object RedisConsumer.consume at 0x11037f220>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 while message := consumer.consume():
#       2     print(message)
#
# KeyboardInterrupt:

# %%
for event in consumer.consume():
    print(event)
# Out:
# {'type': 'subscribe', 'pattern': None, 'channel': b'alerts_stream', 'data': 1}
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 1}}'}
# Event(type='test', payload={'index': 1})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 0}}'}
# Event(type='test', payload={'index': 0})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 1}}'}
# Event(type='test', payload={'index': 1})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 2}}'}
# Event(type='test', payload={'index': 2})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 3}}'}
# Event(type='test', payload={'index': 3})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 4}}'}
# Event(type='test', payload={'index': 4})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 5}}'}
# Event(type='test', payload={'index': 5})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 6}}'}
# Event(type='test', payload={'index': 6})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 7}}'}
# Event(type='test', payload={'index': 7})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 8}}'}
# Event(type='test', payload={'index': 8})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 9}}'}
# Event(type='test', payload={'index': 9})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 10}}'}
# Event(type='test', payload={'index': 10})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 11}}'}
# Event(type='test', payload={'index': 11})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 12}}'}
# Event(type='test', payload={'index': 12})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 13}}'}
# Event(type='test', payload={'index': 13})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 14}}'}
# Event(type='test', payload={'index': 14})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 15}}'}
# Event(type='test', payload={'index': 15})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 16}}'}
# Event(type='test', payload={'index': 16})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 17}}'}
# Event(type='test', payload={'index': 17})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 18}}'}
# Event(type='test', payload={'index': 18})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 19}}'}
# Event(type='test', payload={'index': 19})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 20}}'}
# Event(type='test', payload={'index': 20})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 21}}'}
# Event(type='test', payload={'index': 21})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 22}}'}
# Event(type='test', payload={'index': 22})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 23}}'}
# Event(type='test', payload={'index': 23})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 24}}'}
# Event(type='test', payload={'index': 24})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 25}}'}
# Event(type='test', payload={'index': 25})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 26}}'}
# Event(type='test', payload={'index': 26})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 27}}'}
# Event(type='test', payload={'index': 27})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 28}}'}
# Event(type='test', payload={'index': 28})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 29}}'}
# Event(type='test', payload={'index': 29})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 30}}'}
# Event(type='test', payload={'index': 30})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 31}}'}
# Event(type='test', payload={'index': 31})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 32}}'}
# Event(type='test', payload={'index': 32})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 33}}'}
# Event(type='test', payload={'index': 33})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 34}}'}
# Event(type='test', payload={'index': 34})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 35}}'}
# Event(type='test', payload={'index': 35})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 36}}'}
# Event(type='test', payload={'index': 36})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 37}}'}
# Event(type='test', payload={'index': 37})
# {'type': 'message', 'pattern': None, 'channel': b'alerts_stream', 'data': b'{"type": "test", "payload": {"index": 38}}'}
# Event(type='test', payload={'index': 38})
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for event in consumer.consume():
#       2     print(event)
#
# File ~/projects/ebay_alerts_backend/pubsub/redis_consumer.py:15, in RedisConsumer.consume(self)
#      14 def consume(self) -> Event | None:
# ---> 15     for message in self.pubsub.listen():
#      16         print(message)
#      17         if message['type'] == 'message':
#
# File ~/projects/ebay_alerts_backend/venv/lib/python3.11/site-packages/redis/client.py:1664, in PubSub.listen(self)
#    1662 "Listen for messages on channels this client has been subscribed to"
#    1663 while self.subscribed:
# -> 1664     response = self.handle_message(self.parse_response(block=True))
#    1665     if response is not None:
#    1666         yield response
#
# File ~/projects/ebay_alerts_backend/venv/lib/python3.11/site-packages/redis/client.py:1542, in PubSub.parse_response(self, block, timeout)
#    1539         conn.connect()
#    1540     return conn.read_response(disconnect_on_error=False)
# -> 1542 response = self._execute(conn, try_read)
#    1544 if self.is_health_check_response(response):
#    1545     # ignore the health check message as user might not expect it
#    1546     self.health_check_response_counter -= 1
#
# File ~/projects/ebay_alerts_backend/venv/lib/python3.11/site-packages/redis/client.py:1518, in PubSub._execute(self, conn, command, *args, **kwargs)
#    1510 def _execute(self, conn, command, *args, **kwargs):
#    1511     """
#    1512     Connect manually upon disconnection. If the Redis server is down,
#    1513     this will fail and raise a ConnectionError as desired.
#    (...)
#    1516     patterns we were previously listening to
#    1517     """
# -> 1518     return conn.retry.call_with_retry(
#    1519         lambda: command(*args, **kwargs),
#    1520         lambda error: self._disconnect_raise_connect(conn, error),
#    1521     )
#
# File ~/projects/ebay_alerts_backend/venv/lib/python3.11/site-packages/redis/retry.py:46, in Retry.call_with_retry(self, do, fail)
#      44 while True:
#      45     try:
# ---> 46         return do()
#      47     except self._supported_errors as error:
#      48         failures += 1
#
# File ~/projects/ebay_alerts_backend/venv/lib/python3.11/site-packages/redis/client.py:1519, in PubSub._execute.<locals>.<lambda>()
#    1510 def _execute(self, conn, command, *args, **kwargs):
#    1511     """
#    1512     Connect manually upon disconnection. If the Redis server is down,
#    1513     this will fail and raise a ConnectionError as desired.
#    (...)
#    1516     patterns we were previously listening to
#    1517     """
#    1518     return conn.retry.call_with_retry(
# -> 1519         lambda: command(*args, **kwargs),
#    1520         lambda error: self._disconnect_raise_connect(conn, error),
#    1521     )
#
# File ~/projects/ebay_alerts_backend/venv/lib/python3.11/site-packages/redis/client.py:1540, in PubSub.parse_response.<locals>.try_read()
#    1538 else:
#    1539     conn.connect()
# -> 1540 return conn.read_response(disconnect_on_error=False)
#
# File ~/projects/ebay_alerts_backend/venv/lib/python3.11/site-packages/redis/connection.py:874, in AbstractConnection.read_response(self, disable_decoding, disconnect_on_error)
#     871 host_error = self._host_error()
#     873 try:
# --> 874     response = self._parser.read_response(disable_decoding=disable_decoding)
#     875 except socket.timeout:
#     876     if disconnect_on_error:
#
# File ~/projects/ebay_alerts_backend/venv/lib/python3.11/site-packages/redis/connection.py:347, in PythonParser.read_response(self, disable_decoding)
#     345 pos = self._buffer.get_pos() if self._buffer else None
#     346 try:
# --> 347     result = self._read_response(disable_decoding=disable_decoding)
#     348 except BaseException:
#     349     if self._buffer:
#
# File ~/projects/ebay_alerts_backend/venv/lib/python3.11/site-packages/redis/connection.py:357, in PythonParser._read_response(self, disable_decoding)
#     356 def _read_response(self, disable_decoding=False):
# --> 357     raw = self._buffer.readline()
#     358     if not raw:
#     359         raise ConnectionError(SERVER_CLOSED_CONNECTION_ERROR)
#
# File ~/projects/ebay_alerts_backend/venv/lib/python3.11/site-packages/redis/connection.py:260, in SocketBuffer.readline(self)
#     257 data = buf.readline()
#     258 while not data.endswith(SYM_CRLF):
#     259     # there's more data in the socket that we need
# --> 260     self._read_from_socket()
#     261     data += buf.readline()
#     263 return data[:-2]
#
# File ~/projects/ebay_alerts_backend/venv/lib/python3.11/site-packages/redis/connection.py:210, in SocketBuffer._read_from_socket(self, length, timeout, raise_on_timeout)
#     208 try:
#     209     while True:
# --> 210         data = self._sock.recv(socket_read_size)
#     211         # an empty string indicates the server shutdown the socket
#     212         if isinstance(data, bytes) and len(data) == 0:
#
# KeyboardInterrupt:
